# %% [markdown]
# # Boston Housing

# %% [markdown]
# Nicolás Martínez Gutiérrez

# %% [markdown]
# 751746

# %% [markdown]
# 01/09/2025

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import statsmodels.api as sm

# %%
data = pd.read_excel("Boston Housing Dataset 1978.xlsx")

# %%
data.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data.tail(5)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     1.269195   13.295257    9.205158    0.140765    1.101175   15.679800
# std      2.399207   23.048697    7.169630    0.312765    1.646991   27.220206
# min      0.000000    0.000000    0.000000    0.000000    0.385000    3.561000
# 25%      0.049443    0.000000    3.440000    0.000000    0.449000    5.961500
# 50%      0.144655    0.000000    6.960000    0.000000    0.538000    6.322500
# 75%      0.819623   18.100000   18.100000    0.000000    0.647000    6.949000
# max      9.966540  100.000000   27.740000    1.000000    7.313000  100.000000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    58.744660    6.173308   78.063241  339.317787   42.614980  332.791107
# ...

# %%
data2 = data.dropna()
data2
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
data2.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  452.000000  452.000000  452.000000  452.000000  452.000000  452.000000
# mean     1.420825   12.721239   10.304889    0.077434    0.540816    6.343538
# std      2.495894   24.326032    6.797103    0.267574    0.113816    0.666808
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.069875    0.000000    4.930000    0.000000    0.447000    5.926750
# 50%      0.191030    0.000000    8.140000    0.000000    0.519000    6.229000
# 75%      1.211460   20.000000   18.100000    0.000000    0.605000    6.635000
# max      9.966540  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  452.000000  452.000000  452.000000  452.000000  452.000000  452.000000
# mean    65.557965    4.043570    7.823009  377.442478   18.247124  369.826504
# ...

# %% [markdown]
# ### Regresión Lineal Múltiple

# %%
y = data2["MEDV"]
x = data2.drop(columns=["MEDV"])

# %%
n = len(y)
n
# Out:
# 452

# %%
unos = np.ones([n,1])

# %%
X = np.column_stack([unos, x])

# %%
ols = sm.OLS(y, X)

# %%
results = ols.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.733
# Method:                 Least Squares   F-statistic:                     96.16
# Date:                Mon, 01 Sep 2025   Prob (F-statistic):          2.64e-119
# Time:                        17:43:41   Log-Likelihood:                -1319.4
# No. Observations:                 452   AIC:                             2667.
# Df Residuals:                     438   BIC:                             2724.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         20.8664      5.477      3.810      0.000      10.102      31.631
# ...

# %%
data3 = data2.drop_duplicates()
data3
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
data3.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  452.000000  452.000000  452.000000  452.000000  452.000000  452.000000
# mean     1.420825   12.721239   10.304889    0.077434    0.540816    6.343538
# std      2.495894   24.326032    6.797103    0.267574    0.113816    0.666808
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.069875    0.000000    4.930000    0.000000    0.447000    5.926750
# 50%      0.191030    0.000000    8.140000    0.000000    0.519000    6.229000
# 75%      1.211460   20.000000   18.100000    0.000000    0.605000    6.635000
# max      9.966540  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  452.000000  452.000000  452.000000  452.000000  452.000000  452.000000
# mean    65.557965    4.043570    7.823009  377.442478   18.247124  369.826504
# ...

# %% [markdown]
# ### Escalamiento de Factores

# %%
CRIM_est= (data3["CRIM"] - data3["CRIM"].min()) / (data3["CRIM"].max() - data3["CRIM"].min())

# %%
CRIM_est.min(), CRIM_est.max()
# Out:
# (0.0, 1.0)

# %%
ZN_est   = (data3["ZN"]   - data3["ZN"].min())   / (data3["ZN"].max()   - data3["ZN"].min())

# %%
ZN_est.min(), ZN_est.max()
# Out:
# (0.0, 1.0)

# %%
INDUS_est= (data3["INDUS"]- data3["INDUS"].min())/ (data3["INDUS"].max()- data3["INDUS"].min())

# %%
INDUS_est.min(), INDUS_est.max()
# Out:
# (0.0, 1.0)

# %%
CHAS_est = (data3["CHAS"] - data3["CHAS"].min()) / (data3["CHAS"].max() - data3["CHAS"].min())

# %%
CHAS_est.min(), CHAS_est.max()
# Out:
# (0.0, 1.0)

# %%
NOX_est  = (data3["NOX"]  - data3["NOX"].min())  / (data3["NOX"].max()  - data3["NOX"].min())

# %%
NOX_est.min(), NOX_est.max()
# Out:
# (0.0, 1.0)

# %%
RM_est   = (data3["RM"]   - data3["RM"].min())   / (data3["RM"].max()   - data3["RM"].min())

# %%
RM_est.min(), RM_est.max()
# Out:
# (0.0, 1.0)

# %%
AGE_est  = (data3["AGE"]  - data3["AGE"].min())  / (data3["AGE"].max()  - data3["AGE"].min())

# %%
AGE_est.min(), AGE_est.max()
# Out:
# (0.0, 1.0)

# %%
DIS_est  = (data3["DIS"]  - data3["DIS"].min())  / (data3["DIS"].max()  - data3["DIS"].min())

# %%
DIS_est.min(), DIS_est.max()
# Out:
# (0.0, 1.0)

# %%
RAD_est  = (data3["RAD"]  - data3["RAD"].min())  / (data3["RAD"].max()  - data3["RAD"].min())

# %%
RAD_est.min(), RAD_est.max()
# Out:
# (0.0, 1.0)

# %%
TAX_est  = (data3["TAX"]  - data3["TAX"].min())  / (data3["TAX"].max()  - data3["TAX"].min())

# %%
TAX_est.min(), TAX_est.max()
# Out:
# (0.0, 1.0)

# %%
PTRATIO_est = (data3["PTRATIO"] - data3["PTRATIO"].min()) / (data3["PTRATIO"].max() - data3["PTRATIO"].min())

# %%
PTRATIO_est.min(), PTRATIO_est.max()
# Out:
# (0.0, 1.0)

# %%
B_est    = (data3["B"]    - data3["B"].min())    / (data3["B"].max()    - data3["B"].min())

# %%
B_est.min(), B_est.max()
# Out:
# (0.0, 1.0)

# %%
LSTAT_est= (data3["LSTAT"]- data3["LSTAT"].min())/ (data3["LSTAT"].max()- data3["LSTAT"].min())

# %%
LSTAT_est.min(), LSTAT_est.max()
# Out:
# (0.0, 1.0)

# %%
# for col in data3.columns:
#    if col == "MEDV": break
#    paso1 = data3[col] - data3[col].min()
#    paso2 = paso1/paso1.max()
#    data3[col] = paso2
# print(col)

# %% [markdown]
# ### Regresión Lineal Múltiple después de Escalamiento

# %%
X_est = np.column_stack([CRIM_est, ZN_est, INDUS_est, CHAS_est, NOX_est, RM_est, AGE_est, DIS_est, RAD_est, TAX_est, PTRATIO_est, B_est, LSTAT_est])
y = data3["MEDV"]
n = len(y)
unos = np.ones((n, 1))
X_est = np.column_stack([unos, X_est])
ols = sm.OLS(y, X_est)
results = ols.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.733
# Method:                 Least Squares   F-statistic:                     96.16
# Date:                Mon, 01 Sep 2025   Prob (F-statistic):          2.64e-119
# Time:                        17:43:41   Log-Likelihood:                -1319.4
# No. Observations:                 452   AIC:                             2667.
# Df Residuals:                     438   BIC:                             2724.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         19.9457      2.615      7.626      0.000      14.805      25.086
# ...
